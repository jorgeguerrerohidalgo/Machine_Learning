# %% [markdown]
# # Desafío - Regularización
#
# - Para realizar este desafío debes haber estudiado previamente todo el material disponibilizado correspondiente a la unidad.
# - Una vez terminado el desafío, comprime la carpeta que contiene el desarrollo de los requerimientos solicitados y sube el .zip en el LMS.
# - Desarrollo desafío:
#     - El desafío se debe desarrollar de manera Individual.
#     - Para la realización del desafío necesitarás apoyarte del archivo Apoyo Desafío Regularización.

# %% [markdown]
# ## Requerimientos
# - En esta ocasión utilizaremos datos de la composición química de muestras de vino.
# - Nuestro propósito será tratar de predecir su calidad a partir de su composición química.
# - Comience su estudio realizando un breve análisis exploratorio y descriptivo:
#     - Identifique el tipo de datos de cada columna.
#     - Identifique outliers univariados y multivariados. Los primeros los puede encontrar realizando boxplots de cada atributo, los segundos estudiando los scatterplot entre pares de atributos.
#     - Encuentre la cantidad de valores faltantes en cada columna.
#     - Grafique la distribución empírica de cada atributo

# %% [markdown]
# ### Ejercicio 1: Preparación del ambiente de trabajo
# - Importe las librerías básicas.
# - Importe los métodos asociados a regularización.
# - Importe la base de datos.

# %%
# Utiliza esta celda para realizar los import requeridos y lectura del set de datos
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNetCV

df = pd.read_csv('winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# ### Ejercicio 2: Análisis exploratorio
# - Identifique el tipo de datos de cada columna.
# - Identifique outliers univariados y multivariados.
#     - Los primeros los puede encontrar realizando boxplots de cada atributo.
#     - Los segundos estudiando los scatterplot entre pares de atributos.

# %%
# Utiliza esta celda para identificar el tipo de dato de cada columna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# **Comentarios**

# %%
# Utiliza esta celda para graficar boxplots. Tip: Utilizar df.plot(subplots=True, kind="box")
plt.rcParams['figure.figsize'] = (20, 10)
plt.style.use('seaborn-darkgrid')

for i, (colname, serie) in enumerate (df.iteritems()):
    plt.subplot(4,3, i+1)
    plt.boxplot(x = serie)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# **Comentarios**

# %%
# Utiliza esta celda para graficar scatterplot. Tip: Utilizar pairplot de Seaborn con corner=True. Puedes usar más celdas para graficar subsets

g = sns.PairGrid(df, corner=True, hue='quality')
g.map_diag(sns.histplot)
g.map_lower(sns.scatterplot)

# %% [markdown]
# **Comentarios**

# %% [markdown]
# ### Ejercicio 3: Regularización de modelos
#
# - Genere tres modelos, correspondientes a `RidgeCV` , `LassoCV` y `ElasticNetCV`. Para cada uno de ellos implemente los siguientes pasos:
#     - Entrene los modelos con 10 validaciones cruzadas.
#     - Extraiga los coeficientes estimados, el mejor valor `alpha`, MAE (`median_absolute_error`) y RMSE (raiz cuadrada de `mean_squared_error`) asociado a cada modelo.

# %%
# Utiliza esta celda para entrenar los 3 modelos solicitados

# Divisón de muestras

X = df.drop(columns='quality')
y = df['quality']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=15820)

# Estandarización

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# Entrenamiento modelos

ridge = RidgeCV(cv=10).fit(X_train, y_train)
lasso = LassoCV(cv=10).fit(X_train, y_train)
enet = ElasticNetCV(cv=10).fit(X_train, y_train)

# %%
# Utiliza esta celda para mostrar el mejor alpha y las métricas solicitadas en los 3 modelos
from sklearn.metrics import mean_squared_error, mean_absolute_error

print(f'RMSE: {np.sqrt(mean_squared_error(y_test, ridge.predict(X_test)))}')
print(f'MAE: {mean_absolute_error(y_test, ridge.predict(X_test))}')
print('#'*25)
print(f'RMSE: {np.sqrt(mean_squared_error(y_test, lasso.predict(X_test)))}')
print(f'MAE: {mean_absolute_error(y_test, lasso.predict(X_test))}')
print('#'*25)
print(f'RMSE: {np.sqrt(mean_squared_error(y_test, enet.predict(X_test)))}')
print(f'MAE: {mean_absolute_error(y_test, enet.predict(X_test))}')
# Out:
# RMSE: 0.6813189126278159
# MAE: 0.5287311793104843
# #########################
# RMSE: 0.6801032538183704
# MAE: 0.529464193607739
# #########################
# RMSE: 0.6801646428821702
# MAE: 0.5296496769961924

# %% [markdown]
# **¿Qué modelo presenta un mejor desempeño en base a las métricas?**
#
# **Respuesta**:El modelo que presenta un mejor desempeño es Ridge.

# %%
# Utiliza esta celda para mostrar los coeficientes de los 3 modelos. Tip: Llevarlos a un DF y usar escala de color
df_coeficientes = pd.DataFrame({'Ridge':ridge.coef_,
                                'Lasso':lasso.coef_,
                                'Enet':enet.coef_}, index = X.columns)

# %%
df_coeficientes.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_64b36_row0_col0 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_64b36_row0_col1 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_64b36_row0_col2 {
#   background-color: #fc8969;
#   color: #f1f1f1;
# }
# #T_64b36_row1_col0, #T_64b36_row1_col1, #T_64b36_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_64b36_row2_col0 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_64b36_row2_col1, #T_64b36_row2_col2, #T_64b36_row3_col1, #T_64b36_row3_col2, #T_64b36_row7_col1, #T_64b36_row7_col2 {
#   background-color: #fc8d6d;
#   color: #f1f1f1;
# }
# #T_64b36_row3_col0 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_64b36_row4_col0 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_64b36_row4_col1, #T_64b36_row4_col2 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_64b36_row5_col0 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_64b36_row5_col1 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_64b36_row5_col2 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_64b36_row6_col0 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_64b36_row6_col1, #T_64b36_row6_col2 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_64b36_row7_col0 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_64b36_row8_col0 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_64b36_row8_col1 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_64b36_row8_col2 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_64b36_row9_col0 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_64b36_row9_col1 {
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_64b36_row9_col2 {
#   background-color: #dd2a25;
#   color: #f1f1f1;
# }
# #T_64b36_row10_col0, #T_64b36_row10_col1, #T_64b36_row10_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_64b36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64b36_level0_col0" class="col_heading level0 col0" >Ridge</th>
#       <th id="T_64b36_level0_col1" class="col_heading level0 col1" >Lasso</th>
#       <th id="T_64b36_level0_col2" class="col_heading level0 col2" >Enet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64b36_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_64b36_row0_col0" class="data row0 col0" >0.053404</td>
#       <td id="T_64b36_row0_col1" class="data row0 col1" >0.002797</td>
#       <td id="T_64b36_row0_col2" class="data row0 col2" >0.004486</td>
#     </tr>
#     <tr>
#       <th id="T_64b36_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_64b36_row1_col0" class="data row1 col0" >-0.212018</td>
#       <td id="T_64b36_row1_col1" class="data row1 col1" >-0.198365</td>
#       <td id="T_64b36_row1_col2" class="data row1 col2" >-0.197300</td>
#     </tr>
#     <tr>
#       <th id="T_64b36_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_64b36_row2_col0" class="data row2 col0" >-0.045296</td>
#       <td id="T_64b36_row2_col1" class="data row2 col1" >-0.000000</td>
#       <td id="T_64b36_row2_col2" class="data row2 col2" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_64b36_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_64b36_row3_col0" class="data row3 col0" >0.007698</td>
#       <td id="T_64b36_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_64b36_row3_col2" class="data row3 col2" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_64b36_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_64b36_row4_col0" class="data row4 col0" >-0.073083</td>
#       <td id="T_64b36_row4_col1" class="data row4 col1" >-0.066268</td>
#       <td id="T_64b36_row4_col2" class="data row4 col2" >-0.066776</td>
#     </tr>
#     <tr>
#       <th id="T_64b36_level0_row5" class="row_heading level0 row5" >free sulfur dioxide</th>
#       <td id="T_64b36_row5_col0" class="data row5 col0" >0.066654</td>
#       <td id="T_64b36_row5_col1" class="data row5 col1" >0.039731</td>
#       <td id="T_64b36_row5_col2" class="data row5 col2" >0.040582</td>
#     </tr>
#     <tr>
#       <th id="T_64b36_level0_row6" class="row_heading level0 row6" >total sulfur dioxide</th>
#       <td id="T_64b36_row6_col0" class="data row6 col0" >-0.121606</td>
#       <td id="T_64b36_row6_col1" class="data row6 col1" >-0.100471</td>
#       <td id="T_64b36_row6_col2" class="data row6 col2" >-0.101174</td>
#     </tr>
#     <tr>
#       <th id="T_64b36_level0_row7" class="row_heading level0 row7" >density</th>
#       <td id="T_64b36_row7_col0" class="data row7 col0" >-0.028366</td>
#       <td id="T_64b36_row7_col1" class="data row7 col1" >-0.000000</td>
#       <td id="T_64b36_row7_col2" class="data row7 col2" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_64b36_level0_row8" class="row_heading level0 row8" >pH</th>
#       <td id="T_64b36_row8_col0" class="data row8 col0" >-0.061847</td>
#       <td id="T_64b36_row8_col1" class="data row8 col1" >-0.054569</td>
#       <td id="T_64b36_row8_col2" class="data row8 col2" >-0.053606</td>
#     </tr>
#     <tr>
#       <th id="T_64b36_level0_row9" class="row_heading level0 row9" >sulphates</th>
#       <td id="T_64b36_row9_col0" class="data row9 col0" >0.161873</td>
#       <td id="T_64b36_row9_col1" class="data row9 col1" >0.145857</td>
#       <td id="T_64b36_row9_col2" class="data row9 col2" >0.145631</td>
#     </tr>
#     <tr>
#       <th id="T_64b36_level0_row10" class="row_heading level0 row10" >alcohol</th>
#       <td id="T_64b36_row10_col0" class="data row10 col0" >0.301298</td>
#       <td id="T_64b36_row10_col1" class="data row10 col1" >0.306656</td>
#       <td id="T_64b36_row10_col2" class="data row10 col2" >0.304099</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **¿Qué atributos mantienen un comportamiento similar a lo largo de cada modelo?**
#
# **Respuesta:** LASSO y ELASTICNET mantienen valores similares en comparacion a RIDGGE

# %% [markdown]
# #Los atributos que mantienen un comportamiento similar es alcohol y sulphates

# %%
from sklearn.linear_model import LinearRegression
modelo = LinearRegression().fit(X_train, y_train)
np.sqrt(mean_squared_error(y_test, modelo.predict(X_test)))
# Out:
# 0.6259860000937448

# %%
df_alpha = pd.DataFrame({'Ridge':ridge.alpha_, 'Lasso':lasso.alpha_, 'enet':enet.alpha_}, index = X.columns)
df_alpha
# Out:
#                       Ridge     Lasso      enet
# fixed acidity          10.0  0.008719  0.016263
# volatile acidity       10.0  0.008719  0.016263
# citric acid            10.0  0.008719  0.016263
# residual sugar         10.0  0.008719  0.016263
# chlorides              10.0  0.008719  0.016263
# free sulfur dioxide    10.0  0.008719  0.016263
# total sulfur dioxide   10.0  0.008719  0.016263
# density                10.0  0.008719  0.016263
# pH                     10.0  0.008719  0.016263
# sulphates              10.0  0.008719  0.016263
# alcohol                10.0  0.008719  0.016263

# %%
df_alpha.style.background_gradient(cmap = 'Reds')
# Out:
# <style type="text/css">
# #T_e26ab_row0_col0, #T_e26ab_row0_col1, #T_e26ab_row0_col2, #T_e26ab_row1_col0, #T_e26ab_row1_col1, #T_e26ab_row1_col2, #T_e26ab_row2_col0, #T_e26ab_row2_col1, #T_e26ab_row2_col2, #T_e26ab_row3_col0, #T_e26ab_row3_col1, #T_e26ab_row3_col2, #T_e26ab_row4_col0, #T_e26ab_row4_col1, #T_e26ab_row4_col2, #T_e26ab_row5_col0, #T_e26ab_row5_col1, #T_e26ab_row5_col2, #T_e26ab_row6_col0, #T_e26ab_row6_col1, #T_e26ab_row6_col2, #T_e26ab_row7_col0, #T_e26ab_row7_col1, #T_e26ab_row7_col2, #T_e26ab_row8_col0, #T_e26ab_row8_col1, #T_e26ab_row8_col2, #T_e26ab_row9_col0, #T_e26ab_row9_col1, #T_e26ab_row9_col2, #T_e26ab_row10_col0, #T_e26ab_row10_col1, #T_e26ab_row10_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_e26ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e26ab_level0_col0" class="col_heading level0 col0" >Ridge</th>
#       <th id="T_e26ab_level0_col1" class="col_heading level0 col1" >Lasso</th>
#       <th id="T_e26ab_level0_col2" class="col_heading level0 col2" >enet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e26ab_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_e26ab_row0_col0" class="data row0 col0" >10.000000</td>
#       <td id="T_e26ab_row0_col1" class="data row0 col1" >0.008719</td>
#       <td id="T_e26ab_row0_col2" class="data row0 col2" >0.016263</td>
#     </tr>
#     <tr>
#       <th id="T_e26ab_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_e26ab_row1_col0" class="data row1 col0" >10.000000</td>
#       <td id="T_e26ab_row1_col1" class="data row1 col1" >0.008719</td>
#       <td id="T_e26ab_row1_col2" class="data row1 col2" >0.016263</td>
#     </tr>
#     <tr>
#       <th id="T_e26ab_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_e26ab_row2_col0" class="data row2 col0" >10.000000</td>
#       <td id="T_e26ab_row2_col1" class="data row2 col1" >0.008719</td>
#       <td id="T_e26ab_row2_col2" class="data row2 col2" >0.016263</td>
#     </tr>
#     <tr>
#       <th id="T_e26ab_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_e26ab_row3_col0" class="data row3 col0" >10.000000</td>
#       <td id="T_e26ab_row3_col1" class="data row3 col1" >0.008719</td>
#       <td id="T_e26ab_row3_col2" class="data row3 col2" >0.016263</td>
#     </tr>
#     <tr>
#       <th id="T_e26ab_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_e26ab_row4_col0" class="data row4 col0" >10.000000</td>
#       <td id="T_e26ab_row4_col1" class="data row4 col1" >0.008719</td>
#       <td id="T_e26ab_row4_col2" class="data row4 col2" >0.016263</td>
#     </tr>
#     <tr>
#       <th id="T_e26ab_level0_row5" class="row_heading level0 row5" >free sulfur dioxide</th>
#       <td id="T_e26ab_row5_col0" class="data row5 col0" >10.000000</td>
#       <td id="T_e26ab_row5_col1" class="data row5 col1" >0.008719</td>
#       <td id="T_e26ab_row5_col2" class="data row5 col2" >0.016263</td>
#     </tr>
#     <tr>
#       <th id="T_e26ab_level0_row6" class="row_heading level0 row6" >total sulfur dioxide</th>
#       <td id="T_e26ab_row6_col0" class="data row6 col0" >10.000000</td>
#       <td id="T_e26ab_row6_col1" class="data row6 col1" >0.008719</td>
#       <td id="T_e26ab_row6_col2" class="data row6 col2" >0.016263</td>
#     </tr>
#     <tr>
#       <th id="T_e26ab_level0_row7" class="row_heading level0 row7" >density</th>
#       <td id="T_e26ab_row7_col0" class="data row7 col0" >10.000000</td>
#       <td id="T_e26ab_row7_col1" class="data row7 col1" >0.008719</td>
#       <td id="T_e26ab_row7_col2" class="data row7 col2" >0.016263</td>
#     </tr>
#     <tr>
#       <th id="T_e26ab_level0_row8" class="row_heading level0 row8" >pH</th>
#       <td id="T_e26ab_row8_col0" class="data row8 col0" >10.000000</td>
#       <td id="T_e26ab_row8_col1" class="data row8 col1" >0.008719</td>
#       <td id="T_e26ab_row8_col2" class="data row8 col2" >0.016263</td>
#     </tr>
#     <tr>
#       <th id="T_e26ab_level0_row9" class="row_heading level0 row9" >sulphates</th>
#       <td id="T_e26ab_row9_col0" class="data row9 col0" >10.000000</td>
#       <td id="T_e26ab_row9_col1" class="data row9 col1" >0.008719</td>
#       <td id="T_e26ab_row9_col2" class="data row9 col2" >0.016263</td>
#     </tr>
#     <tr>
#       <th id="T_e26ab_level0_row10" class="row_heading level0 row10" >alcohol</th>
#       <td id="T_e26ab_row10_col0" class="data row10 col0" >10.000000</td>
#       <td id="T_e26ab_row10_col1" class="data row10 col1" >0.008719</td>
#       <td id="T_e26ab_row10_col2" class="data row10 col2" >0.016263</td>
#     </tr>
#   </tbody>
# </table>
